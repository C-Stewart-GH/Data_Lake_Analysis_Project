# %% [markdown]
# # Pulling Tweets
# First we will be pulling Tweets from Twitter. This will be following direction of:https://towardsdatascience.com/streaming-twitter-data-into-a-mysql-database-d62a02b050d6
#
# The second part will be structuring the data and then importing it into a traditional RDBMS.

# %%
import mysql.connector
from mysql.connector import Error
import tweepy
import json
from dateutil import parser
import time
import os
import subprocess

# %%
TWITTER_CONSUMER_KEY = "secret"
TWITTER_CONSUMER_SECRET = "secret"
TWITTER_ACCESS_TOKEN = "secret"
TWITTER_ACCESS_TOKEN_SECRET = "secret"

# %% [markdown]
# #### connect to MySQL database and insert twitter data

# %%
def connect(created_at, tweet, retweet_count, location):

    try:
            con = mysql.connector.connect(host = 'localhost',
            database='twitterdb', user='root', password = 'NED@smu2021', charset = 'utf8')

            if con.is_connected():

                cursor = con.cursor()
                query = "INSERT INTO tweets (created_at, tweet, retweet_count, location) VALUES ( %s, %s, %s, %s)"
                cursor.execute(query, (created_at, tweet, retweet_count, location))
                con.commit()


    except Error as e:
        print(e)

    cursor.close()
    con.close()

    return


# Tweepy class to access Twitter API
class Streamlistener(tweepy.StreamListener):


    def on_connect(self):
        print("You are connected to the Twitter API")


    def on_error(self):
        if status_code != 200:
            print("error found")
            # returning false disconnects the stream
            return False


    def on_data(self,data):
        
        try:
            raw_data = json.loads(data)

            if 'text' in raw_data:
                 
                created_at = parser.parse(raw_data['created_at'])
                tweet = raw_data['text']
                retweet_count = raw_data['retweet_count']
                location = raw_data['user']['location']

                #insert data just collected into MySQL database
                connect(created_at, tweet, retweet_count, location)
                print("Tweet colleted at: {} ".format(str(created_at)))
        except Error as e:
            print(e)


if __name__== '__main__':

# authentification so we can access twitter
    auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
    auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
    api = tweepy.API(auth,wait_on_rate_limit=True)

# create instance of Streamlistener
    listener = Streamlistener(api = api)
    stream = tweepy.Stream(auth, listener = listener)

    track = ['covid-19']
    stream.filter(track = track, languages = ['en'])
# Out:
# You are connected to the Twitter API
# Tweet colleted at: 2021-07-20 03:20:15+00:00
# Tweet colleted at: 2021-07-20 03:20:15+00:00
# Tweet colleted at: 2021-07-20 03:20:15+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# 1366 (HY000): Incorrect string value: '\xF0\x9F\x87\xB2\xF0\x9F...' for column 'Tweet' at row 1
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:16+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:17+00:00
# Tweet colleted at: 2021-07-20 03:20:18+00:00
# Tweet colleted at: 2021-07-20 03:20:18+00:00
# ...
