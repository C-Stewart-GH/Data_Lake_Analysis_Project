# %% [markdown]
# # Get Tweets
#
# This Notbook heavily references this notebook for gathering tweets: https://github.com/alod83/data-science/blob/master/DataCollection/Twitter/get_tweets.ipynb
#
# This Notebook references this link for uploading tweets to MongoDB: https://medium.com/analytics-vidhya/how-to-upload-a-pandas-dataframe-to-mongodb-ffa18c0953c1
#
# This script extracts all the tweets with hashtag #covid-19 related to the day before today (yesterday) and saves them into a .csv file.
# We use the `tweepy` library, which can be installed with the command `pip install tweepy`.
#
# Firstly, we import the configuration file, called `config.py`, which is located in the same directory of this script.

# %%
import tweepy
import datetime

# %% [markdown]
# We setup the connection to our Twitter App by using the `OAuthHandler()` class and its `access_token()` function. Then we call the Twitter API through the `API()` function.

# %%
auth = tweepy.OAuthHandler(TWITTER_CONSUMER_KEY, TWITTER_CONSUMER_SECRET)
auth.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %% [markdown]
# Now we setup dates. We need to setup today and yesterday.

# %%
today = datetime.date.today()
yesterday= today - datetime.timedelta(days=1)
today, yesterday
# Out:
# (datetime.date(2021, 7, 7), datetime.date(2021, 7, 6))

# %% [markdown]
# We search for tweets on Twitter by using the `Cursor()` function.
# We pass the `api.search` parameter to the cursor, as well as the query string, which is specified through the `q` parameter of the cursor.
# The query string can receive many parameters, such as the following (not mandatory) ones:
# * `from:` - to specify a specific Twitter user profile
# * `since:` - to specify the beginning date of search
# * `until:` - to specify the ending date of search
# The cursor can also receive other parameters, such as the language and the `tweet_mode`. If `tweet_mode='extended'`, all the text of the tweet is returned, otherwise only the first 140 characters.

# %%
tweets_list = tweepy.Cursor(api.search, q="#DataLake since:" + str(yesterday)+ " until:" + str(today),tweet_mode='extended', lang='en').items()

# %% [markdown]
# Now we loop across the `tweets_list`, and, for each tweet, we extract the text, the creation date, the number of retweets and the favourite count. We store every tweet into a list, called `output`.

# %%
output = []
for tweet in tweets_list:
    text = tweet._json["full_text"]
    print(text)
    favourite_count = tweet.favorite_count
    retweet_count = tweet.retweet_count
    created_at = tweet.created_at
    
    line = {'text' : text, 'favourite_count' : favourite_count, 'retweet_count' : retweet_count, 'created_at' : created_at}
    output.append(line)
# Out:
# RT @FactionInc: Helping enterprise architects unpack today’s cloud data challenges and select the most valuable and cost-effective solution…
# Helping enterprise architects unpack today’s cloud data challenges and select the most valuable and cost-effective solution for your organization. Download the new white paper to learn more: https://t.co/PlT9NWTYwH #datawarehouse #datalake #enterprisearchitect #clouddata https://t.co/4uwxrCy7Yq
# Ready to speed up your Presto queries?🎉 Sign up for a free trial of Ahana Cloud! We’ll be there if you get stuck. 👉👉https://t.co/zyBSIZadXK
#
# #saas @prestodb #AWS #S3data #datalake https://t.co/SBRHPPD2zZ
# #Gartner research says 61% of organisations are using a Data Warehouse as part of their infrastructure. Read the #NewYear #Blog from #DataVault  here https://t.co/Q0CJdh17Qy for some great insight into #DataWarehouse #BIWisdom  #CIO #DataLake #DataHub https://t.co/ipf7AkptOV
# When do you use #data virtualization vs. ETL?
#
# I just can't imagine why you would need it if you had a decent #datalake.
#
# Am I missing something?
# RT @williammcknight: I’m on the latest #DataLeadershipLessons #Podcast with @AJAlgmin. I’m talking #data #datawarehouse #datalake #datascie…
# RT @dremio: #ScholaryTuesday - Data Lake vs Data Warehouse - The Myth, The Reality and The Benefits
# https://t.co/UNLzLwwSx4
# #Data #DataLake…
# #ScholaryTuesday - Data Lake vs Data Warehouse - The Myth, The Reality and The Benefits
# https://t.co/UNLzLwwSx4
# #Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource
# To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS shares its lessons learned.
# https://t.co/V474QDX1LP
# #datalake #database #insurance https://t.co/EGVAadTH1a
# RT @dremio: Apache Iceberg: An Architectural Look Under the Covers
# https://t.co/ODcscg9Hc6
# #Data #DataLake #Analytics #DataManagement #Lak…
# Apache Iceberg: An Architectural Look Under the Covers
# https://t.co/ODcscg9Hc6
# #Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource
# RT @dremio: #Webinar - Top 10 Dremio and AWS Best Practices for Data Lakes. Learn how to transform your cloud data lake analytics with @AWS…
# #Webinar - Top 10 Dremio and AWS Best Practices for Data Lakes. Learn how to transform your cloud data lake analytics with @AWS_Partners .
# Register Now: https://t.co/ddcb7iFPdP
# #Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #AWS https://t.co/NIX0wFWpZY
# RT @dremio: 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!
# https://t.co/76NtPs02xo
# #…
# RT @SubsurfaceConf: 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!
# https://t.co/asGt…
# 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!
# https://t.co/76NtPs02xo
# #Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #Subsurface https://t.co/COKEJIJz7j
# 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!
# https://t.co/asGtPedshf
# #Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #Subsurface https://t.co/JhCmmJLu0B
# This is a must-attend FREE conference: 2 days, 30+ sessions on how to innovate with open source technologies such as Arrow, Iceberg, Nessie, Delta Lake, Airflow, Dagster, Superset, Druid, and more. Register today!  #DataLake #DataAnalytics  https://t.co/iOKKCwFP52
# What does #DataVault2 architecture look like? In the third of our short videos for beginners, we explore the architecture of Data Vault 2.0. #DataLake #DataMart and more. Watch here https://t.co/xDwOLSB3BJ #EnterpriseData #DataModelling #AgileDW #Analytics #data #YouTube #EDW https://t.co/xuI2jsNrjL
# #Gartner research says 61% of organisations are using a Data Warehouse as part of their infrastructure. Read the #NewYear #Blog from #DataVault  here https://t.co/Q0CJdh17Qy for some great insight into #DataWarehouse #BIWisdom  #CIO #DataLake #DataHub https://t.co/NoPdbMhVr0
# RT @NEOSLLC: To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS sha…
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS shares its lessons learned.
# https://t.co/ugkrh5fDRR
# #datalake #database #insurance https://t.co/eyuMiTvCdO
# RT @ume_kyd: Focus on where you really want to go
# New journey is on💥
#
# Discover your #data
# Gain insight of the future with #DataAnalytics
# Co…
# RT @xbsoftware: Some say data lake and data warehouse notions are interchangeable. In the article we define the main difference between the…
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# Some say data lake and data warehouse notions are interchangeable. In the article we define the main difference between them and give some tips on how to choose more suitable approach:
# https://t.co/bXzpG1ZzZt
# #BigData #DataLake #DataWarehouse
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# RT @preset_data: Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-perf…
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…
# Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence, #bigdata, #blockchain, #cybersecurity, #datalake, #datascience, #deeplearning, #hadoop, #machinelearning, #neuralnetworks, #nlp, #textanalytics
# What does #DataVault2 architecture look like? In the third of our short videos for beginners, we explore the architecture of Data Vault 2.0. #DataLake #DataMart and more. Watch here https://t.co/xDwOLSB3BJ #EnterpriseData #Datamodelling @WhereScape #Analytics #data #YouTube #IBM https://t.co/ihIz12lbyt
# RT @preset_data: Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-perf…
# Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-performance #datalake visualization using #Dremio and #ApacheSuperset 📊! Don't forget to register ➡️ https://t.co/j2Jq0UzY54
#
# #DataVisualization #OpenSource
# RT @AnalyticsFrance: Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/ocPJvnUIUy - thanks @RichardEud…
# RT @BigData_Fr: via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #c…
# RT @BigData_Fr: via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #c…
# via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/lk5yoWmCwj
# Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/ocPJvnUIUy - thanks @RichardEudes #Analytics,#BigData,#Supplychain,#Compliance,#Cybersecurity,#DataEngineering,#DataGovernance,#DataLake,#DataManagement,#DataPrivacy,#DigitalTransformation,#G…
# Adelaide's new Women's and Children's Hospital sparks contention over treatment spaces - https://t.co/Ht8SyTI6Ei - thanks @RichardEudes #Analytics,#BigData,#DataLake,#Hadoop
# RT @DataScientistsF: Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/blkOcwmW8l - thanks @RichardEu…
# Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/blkOcwmW8l - thanks @RichardEudes #DataScience #DS,#BigData,#DataEngineering,#DataLake,#DataManagement
# via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/nrxuLxlswg #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/JW17jWecEg
# Airbnb has blocked tens of thousands of bookings in party crackdown - https://t.co/5Lpf8dk6PJ - thanks @RichardEudes #Analytics,#BigData,#DataEngineering,#DataLake,#DataManagement
# via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/fv99qm0CZ9 #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/nA9rtuUEha
# Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/aoj8qleZiu - thanks @RichardEudes #DataScience #DS,#BigData,#Supplychain,#Compliance,#Cybersecurity,#DataEngineering,#DataGovernance,#DataLake,#DataManagement,#DataPrivacy,#DigitalTransformat…
# Gamestop – Exchange leaders say GameStop saga highlights regulatory challenges - https://t.co/Oyy5JGtXaM - thanks @RichardEudes #DataScience #DS,#BigData,#DataLake,#Hadoop
# Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/Q6uMsn0B6n - thanks @RichardEudes #DataScience #DS,#BigData,#DataEngineering,#DataLake,#DataManagement
# Best Big Data Courses for Beginners to Ace the Technology https://t.co/DZbpazbzUZ #analytics, #analytics #datascience, #artificialintelligence, #bigdata, #businessanalytics, #businessanalytics #ba, #dataengineering, #datagovernance, #datalake, #datamanagement, #datascience, #ha…
# RT @qubole: In this video we focus XGBoost (a distributed #machinelearning algorithm) &amp; the Telco Customer Churn Dataset to train &amp; predict…
# In this video we focus XGBoost (a distributed #machinelearning algorithm) &amp; the Telco Customer Churn Dataset to train &amp; predict Customer Churn using automated #ApacheSpark #ML pipelines.
# Full video - https://t.co/8ZFgkkUXTf
# #datalake #datalakes #dataengineering #datascience #data https://t.co/P7zRPX2XL4
# Top Data Visualization Tools for 2021 https://t.co/MPzRs3QuQV #analytics #datascience, #artificialintelligence, #bi, #bigdata, #businessanalytics #ba, #businessintelligence, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience
# RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…
# RT @dremio: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Summer 202…
# RT @dremio: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Summer 202…
# RT @SubsurfaceConf: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Su…
# RT @SubsurfaceConf: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Su…
# RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…
# RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…
# RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…

# %%
output
# Out:
# [{'text': 'RT @FactionInc: Helping enterprise architects unpack today’s cloud data challenges and select the most valuable and cost-effective solution…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 23, 58, 1)},
#  {'text': 'Helping enterprise architects unpack today’s cloud data challenges and select the most valuable and cost-effective solution for your organization. Download the new white paper to learn more: https://t.co/PlT9NWTYwH #datawarehouse #datalake #enterprisearchitect #clouddata https://t.co/4uwxrCy7Yq',
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 23, 57, 43)},
#  {'text': 'Ready to speed up your Presto queries?🎉 Sign up for a free trial of Ahana Cloud! We’ll be there if you get stuck. 👉👉https://t.co/zyBSIZadXK\n\n#saas @prestodb #AWS #S3data #datalake https://t.co/SBRHPPD2zZ',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 23, 12)},
#  {'text': '#Gartner research says 61% of organisations are using a Data Warehouse as part of their infrastructure. Read the #NewYear #Blog from #DataVault  here https://t.co/Q0CJdh17Qy for some great insight into #DataWarehouse #BIWisdom  #CIO #DataLake #DataHub https://t.co/ipf7AkptOV',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 21, 20)},
#  {'text': "When do you use #data virtualization vs. ETL? \n\nI just can't imagine why you would need it if you had a decent #datalake.\n\nAm I missing something?",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 21, 17, 27)},
#  {'text': 'RT @williammcknight: I’m on the latest #DataLeadershipLessons #Podcast with @AJAlgmin. I’m talking #data #datawarehouse #datalake #datascie…',
#   'favourite_count': 0,
#   'retweet_count': 5,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 45, 59)},
#  {'text': 'RT @dremio: #ScholaryTuesday - Data Lake vs Data Warehouse - The Myth, The Reality and The Benefits\nhttps://t.co/UNLzLwwSx4\n#Data #DataLake…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 4, 32)},
#  {'text': '#ScholaryTuesday - Data Lake vs Data Warehouse - The Myth, The Reality and The Benefits\nhttps://t.co/UNLzLwwSx4\n#Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource',
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 4, 27)},
#  {'text': 'To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS shares its lessons learned. \nhttps://t.co/V474QDX1LP\n#datalake #database #insurance https://t.co/EGVAadTH1a',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 4, 3)},
#  {'text': 'RT @dremio: Apache Iceberg: An Architectural Look Under the Covers \nhttps://t.co/ODcscg9Hc6\n#Data #DataLake #Analytics #DataManagement #Lak…',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 0, 24)},
#  {'text': 'Apache Iceberg: An Architectural Look Under the Covers \nhttps://t.co/ODcscg9Hc6\n#Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource',
#   'favourite_count': 2,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 7, 6, 20, 0, 19)},
#  {'text': 'RT @dremio: #Webinar - Top 10 Dremio and AWS Best Practices for Data Lakes. Learn how to transform your cloud data lake analytics with @AWS…',
#   'favourite_count': 0,
#   'retweet_count': 5,
#   'created_at': datetime.datetime(2021, 7, 6, 18, 34, 11)},
#  {'text': '#Webinar - Top 10 Dremio and AWS Best Practices for Data Lakes. Learn how to transform your cloud data lake analytics with @AWS_Partners .\nRegister Now: https://t.co/ddcb7iFPdP\n#Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #AWS https://t.co/NIX0wFWpZY',
#   'favourite_count': 3,
#   'retweet_count': 5,
#   'created_at': datetime.datetime(2021, 7, 6, 18, 34, 6)},
#  {'text': 'RT @dremio: 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!\nhttps://t.co/76NtPs02xo\n#…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 17, 50, 14)},
#  {'text': 'RT @SubsurfaceConf: 2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!\nhttps://t.co/asGt…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 17, 50, 12)},
#  {'text': '2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!\nhttps://t.co/76NtPs02xo\n#Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #Subsurface https://t.co/COKEJIJz7j',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 17, 50, 9)},
#  {'text': '2 weeks left until Subsurface Live!! Learn from experts who are leading the innovation. Register now!\nhttps://t.co/asGtPedshf\n#Data #DataLake #Analytics #DataManagement #Lakehouse #OpenSource #Subsurface https://t.co/JhCmmJLu0B',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 17, 50, 7)},
#  {'text': 'This is a must-attend FREE conference: 2 days, 30+ sessions on how to innovate with open source technologies such as Arrow, Iceberg, Nessie, Delta Lake, Airflow, Dagster, Superset, Druid, and more. Register today!  #DataLake #DataAnalytics  https://t.co/iOKKCwFP52',
#   'favourite_count': 1,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 16, 0, 4)},
#  {'text': 'What does #DataVault2 architecture look like? In the third of our short videos for beginners, we explore the architecture of Data Vault 2.0. #DataLake #DataMart and more. Watch here https://t.co/xDwOLSB3BJ #EnterpriseData #DataModelling #AgileDW #Analytics #data #YouTube #EDW https://t.co/xuI2jsNrjL',
#   'favourite_count': 2,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 15, 50)},
#  {'text': '#Gartner research says 61% of organisations are using a Data Warehouse as part of their infrastructure. Read the #NewYear #Blog from #DataVault  here https://t.co/Q0CJdh17Qy for some great insight into #DataWarehouse #BIWisdom  #CIO #DataLake #DataHub https://t.co/NoPdbMhVr0',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 14, 25)},
#  {'text': 'RT @NEOSLLC: To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS sha…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 13, 58, 2)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 13, 3, 22)},
#  {'text': 'To efficiently ingest data into a data lake, your team must properly evaluate the environment and technology choices. NEOS shares its lessons learned. \nhttps://t.co/ugkrh5fDRR\n#datalake #database #insurance https://t.co/eyuMiTvCdO',
#   'favourite_count': 1,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 13, 0, 49)},
#  {'text': 'RT @ume_kyd: Focus on where you really want to go\nNew journey is on💥\n\nDiscover your #data\nGain insight of the future with #DataAnalytics\nCo…',
#   'favourite_count': 0,
#   'retweet_count': 142,
#   'created_at': datetime.datetime(2021, 7, 6, 12, 59, 55)},
#  {'text': 'RT @xbsoftware: Some say data lake and data warehouse notions are interchangeable. In the article we define the main difference between the…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 12, 55, 4)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 12, 54, 25)},
#  {'text': 'Some say data lake and data warehouse notions are interchangeable. In the article we define the main difference between them and give some tips on how to choose more suitable approach:\nhttps://t.co/bXzpG1ZzZt\n#BigData #DataLake #DataWarehouse',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 12, 28, 45)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 44, 18)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 44, 12)},
#  {'text': 'RT @preset_data: Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-perf…',
#   'favourite_count': 0,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 40, 33)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 40, 25)},
#  {'text': 'RT @RichardEudes: Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence,…',
#   'favourite_count': 0,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 40, 4)},
#  {'text': 'Top 10 Data Science Coding Schools for Boosting Your Career https://t.co/d5dnjWwXKq #analytics, #artificialintelligence, #bigdata, #blockchain, #cybersecurity, #datalake, #datascience, #deeplearning, #hadoop, #machinelearning, #neuralnetworks, #nlp, #textanalytics',
#   'favourite_count': 9,
#   'retweet_count': 10,
#   'created_at': datetime.datetime(2021, 7, 6, 10, 40)},
#  {'text': 'What does #DataVault2 architecture look like? In the third of our short videos for beginners, we explore the architecture of Data Vault 2.0. #DataLake #DataMart and more. Watch here https://t.co/xDwOLSB3BJ #EnterpriseData #Datamodelling @WhereScape #Analytics #data #YouTube #IBM https://t.co/ihIz12lbyt',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 9, 15)},
#  {'text': 'RT @preset_data: Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-perf…',
#   'favourite_count': 0,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2021, 7, 6, 9, 0, 58)},
#  {'text': "Today at 10:00am PDT Robert Stoltz from @preset_data and @BigDataBrett from @dremio will be doing a live-demo on high-performance #datalake visualization using #Dremio and #ApacheSuperset 📊! Don't forget to register ➡️ https://t.co/j2Jq0UzY54\n\n#DataVisualization #OpenSource",
#   'favourite_count': 5,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2021, 7, 6, 9, 0, 53)},
#  {'text': 'RT @AnalyticsFrance: Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/ocPJvnUIUy - thanks @RichardEud…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 8, 56, 21)},
#  {'text': 'RT @BigData_Fr: via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #c…',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 52, 30)},
#  {'text': 'RT @BigData_Fr: via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #c…',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 49, 26)},
#  {'text': 'via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/5HY8oQhTWW #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/lk5yoWmCwj',
#   'favourite_count': 0,
#   'retweet_count': 3,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 46, 20)},
#  {'text': 'Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/ocPJvnUIUy - thanks @RichardEudes #Analytics,#BigData,#Supplychain,#Compliance,#Cybersecurity,#DataEngineering,#DataGovernance,#DataLake,#DataManagement,#DataPrivacy,#DigitalTransformation,#G…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 44, 42)},
#  {'text': "Adelaide's new Women's and Children's Hospital sparks contention over treatment spaces - https://t.co/Ht8SyTI6Ei - thanks @RichardEudes #Analytics,#BigData,#DataLake,#Hadoop",
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 44, 41)},
#  {'text': 'RT @DataScientistsF: Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/blkOcwmW8l - thanks @RichardEu…',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 39, 26)},
#  {'text': 'Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/blkOcwmW8l - thanks @RichardEudes #DataScience #DS,#BigData,#DataEngineering,#DataLake,#DataManagement',
#   'favourite_count': 0,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 32, 17)},
#  {'text': 'via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/nrxuLxlswg #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/JW17jWecEg',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 22, 19)},
#  {'text': 'Airbnb has blocked tens of thousands of bookings in party crackdown - https://t.co/5Lpf8dk6PJ - thanks @RichardEudes #Analytics,#BigData,#DataEngineering,#DataLake,#DataManagement',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 17, 20)},
#  {'text': 'via @RichardEudes - Why ETL Needs Open Source to Address the Long Tail of Integrations https://t.co/fv99qm0CZ9 #bigdata, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience, #datascience #ds, #gdpr https://t.co/nA9rtuUEha',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 13, 35)},
#  {'text': 'Powering the Digital Next CPG Enterprise with Platforms of Intelligence - https://t.co/aoj8qleZiu - thanks @RichardEudes #DataScience #DS,#BigData,#Supplychain,#Compliance,#Cybersecurity,#DataEngineering,#DataGovernance,#DataLake,#DataManagement,#DataPrivacy,#DigitalTransformat…',
#   'favourite_count': 1,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 9, 47)},
#  {'text': 'Gamestop – Exchange leaders say GameStop saga highlights regulatory challenges - https://t.co/Oyy5JGtXaM - thanks @RichardEudes #DataScience #DS,#BigData,#DataLake,#Hadoop',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 9, 44)},
#  {'text': 'Picture perfect: Chinese tourists flock to lake to recreate viral photos - https://t.co/Q6uMsn0B6n - thanks @RichardEudes #DataScience #DS,#BigData,#DataEngineering,#DataLake,#DataManagement',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 7, 9, 42)},
#  {'text': 'Best Big Data Courses for Beginners to Ace the Technology https://t.co/DZbpazbzUZ #analytics, #analytics #datascience, #artificialintelligence, #bigdata, #businessanalytics, #businessanalytics #ba, #dataengineering, #datagovernance, #datalake, #datamanagement, #datascience, #ha…',
#   'favourite_count': 0,
#   'retweet_count': 0,
#   'created_at': datetime.datetime(2021, 7, 6, 6, 30, 15)},
#  {'text': 'RT @qubole: In this video we focus XGBoost (a distributed #machinelearning algorithm) &amp; the Telco Customer Churn Dataset to train &amp; predict…',
#   'favourite_count': 0,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2021, 7, 6, 5, 31, 12)},
#  {'text': 'In this video we focus XGBoost (a distributed #machinelearning algorithm) &amp; the Telco Customer Churn Dataset to train &amp; predict Customer Churn using automated #ApacheSpark #ML pipelines.\nFull video - https://t.co/8ZFgkkUXTf\n#datalake #datalakes #dataengineering #datascience #data https://t.co/P7zRPX2XL4',
#   'favourite_count': 2,
#   'retweet_count': 2,
#   'created_at': datetime.datetime(2021, 7, 6, 5, 30, 47)},
#  {'text': 'Top Data Visualization Tools for 2021 https://t.co/MPzRs3QuQV #analytics #datascience, #artificialintelligence, #bi, #bigdata, #businessanalytics #ba, #businessintelligence, #compliance, #dataengineering, #datagovernance, #datalake, #datamanagement, #dataprivacy, #datascience',
#   'favourite_count': 2,
#   'retweet_count': 1,
#   'created_at': datetime.datetime(2021, 7, 6, 5, 24, 28)},
#  {'text': 'RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…',
#   'favourite_count': 0,
#   'retweet_count': 8,
#   'created_at': datetime.datetime(2021, 7, 6, 4, 38, 16)},
#  {'text': 'RT @dremio: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Summer 202…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 7, 6, 3, 58, 48)},
#  {'text': 'RT @dremio: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Summer 202…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 7, 6, 3, 58, 43)},
#  {'text': 'RT @SubsurfaceConf: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Su…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 7, 6, 3, 58, 43)},
#  {'text': 'RT @SubsurfaceConf: If data is on your mind then meet us at the biggest gathering of data lake experts. Register now for Subsurface LIVE Su…',
#   'favourite_count': 0,
#   'retweet_count': 4,
#   'created_at': datetime.datetime(2021, 7, 6, 3, 58, 37)},
#  {'text': 'RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…',
#   'favourite_count': 0,
#   'retweet_count': 8,
#   'created_at': datetime.datetime(2021, 7, 6, 2, 36, 58)},
#  {'text': 'RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…',
#   'favourite_count': 0,
#   'retweet_count': 8,
#   'created_at': datetime.datetime(2021, 7, 6, 2, 12, 13)},
#  {'text': 'RT @RichardEudes: Top Data Visualization Tools for 2021 https://t.co/FZsxqj7OyV #analytics #datascience, #artificialintelligence, #bi, #big…',
#   'favourite_count': 0,
#   'retweet_count': 8,
#   'created_at': datetime.datetime(2021, 7, 6, 1, 52, 4)}]

# %% [markdown]
# Finally, we convert the `output` list to a `pandas DataFrame` and we store results.

# %%
import pandas as pd

df = pd.DataFrame(output)
df.to_csv('output.csv', mode='a', header=False)
#df.to_csv('output.csv')

# %%
df.shape
# Out:
# (62, 4)

# %%
df.head(10)
# Out:
#                                                 text  favourite_count  \
# 0  RT @FactionInc: Helping enterprise architects ...                0
# 1  Helping enterprise architects unpack today’s c...                2
# 2  Ready to speed up your Presto queries?🎉 Sign u...                1
# 3  #Gartner research says 61% of organisations ar...                0
# 4  When do you use #data virtualization vs. ETL? ...                0
# 5  RT @williammcknight: I’m on the latest #DataLe...                0
# 6  RT @dremio: #ScholaryTuesday - Data Lake vs Da...                0
# 7  #ScholaryTuesday - Data Lake vs Data Warehouse...                2
# 8  To efficiently ingest data into a data lake, y...                1
# 9  RT @dremio: Apache Iceberg: An Architectural L...                0
#
#    retweet_count          created_at
# 0              1 2021-07-06 23:58:01
# 1              1 2021-07-06 23:57:43
# 2              0 2021-07-06 23:12:00
# 3              0 2021-07-06 21:20:00
# 4              0 2021-07-06 21:17:27
# 5              5 2021-07-06 20:45:59
# 6              1 2021-07-06 20:04:32
# 7              1 2021-07-06 20:04:27
# 8              0 2021-07-06 20:04:03
# 9              3 2021-07-06 20:00:24

# %% [markdown]
# Upload pandas df with #DataLake tweets to MongoDB

# %%
import pandas as pd
import pymongo
from pymongo import MongoClient

# %%
# Making a Connection with MongoClient
client = pymongo.MongoClient("mongodb+srv://c_stewart:<password>@cscluster.wzvbj.mongodb.net/Twitter_Data?retryWrites=true&w=majority")
# database
db = client["Twitter_Data"]
# collection
collection= db["Tweets_About_Data_Lakes"]

# %%
df.reset_index(inplace=True)
data_dict = df.to_dict("records")
# Insert collection
collection.insert_many(data_dict)
